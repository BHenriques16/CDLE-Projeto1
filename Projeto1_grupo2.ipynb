# %% [markdown]
# # 1. Basic Information

# %% [markdown]
# Aquisição, Armazenamento e Recuperação de Dados em Larga Escala
#
# - Grupo 2: Bernardo Henriques nº52365
# - Guilherme Cardoso nº51631
# - Dinis Amado nº51556

# %% [markdown]
# ### Declaração de Integridade
#
# Eu, Bernardo Henriques, Guilherme Cardoso e Dinis Amado, estudantes com os números de inscrição 52365, 51631 e 51556 (respetivamente) de/o 1º Ciclo em Inteligência Artificial e Ciência de Dados da Universidade da Beira Interior, declaro ter desenvolvido o presente trabalho e elaborado o presente texto em total consonância com o Código de Integridade da Universidade da Beira Interior. Mais concretamente afirmo não ter incorrido em qualquer das variedades de Fraude Académica, e que aqui declaro conhecer, que em particular atendi à exigida referenciação de frases, extratos, imagens e outras formas de trabalho intelectual, e assumindo assim na íntegra as responsabilidades da autoria.
#
# Universidade da Beria Interior
#
# 30/04/2026

# %% [markdown]
# ### Declaração do uso de IA Generativa
#
# De acordo com as diretrizes do projeto, declaramos o uso das seguintes ferramentas de Inteligência Artificial Generativa na preparação deste trabalho:
#
# * **Ferramentas e serviços usados:** Google Gemini e Claude.
# * **Contribuições das ferramentas:** Tanto o Gemini como o Claude foram utilizados como assistentes de desenvolvimento para auxílio no debug de código Python, estruturação de comandos Docker para a infraestrutura da base de dados e no esclarecimento de dúvidas sobre a gestão do repositório Git/GitHub. Todo o código final, decisões arquiteturais e redação de conteúdos foram revistos, testados e validados por nós.

# %% [markdown]
# # 2. Contribution
#
# | Aluno | Horas de trabalho | Contributos Detalhados |
# | :--- | :--- | :--- |
# | Bernardo Henriques | 11h | Configuração do repositório Git/GitHub; Implementação da infraestrutura de base de dados Redis através do Docker; Desenvolvimento das queries de pesquisa e redação do Notebook. |
# | Guilherme Cardoso | 11h30 min | Desenvolvimento e otimização dos módulos de Web Scraping em Python e automatização contínua do pipeline de dados através de GitHub Actions. |
# | Dinis Amado | 10h | Desenvolvimento de uma arquitetura de web scraping em Python de portais tecnológicos, manutenção e tratamento de problemas. Criação de uma pipeline de extração estruturada para armazenamento persistente em JSON. |

# %% [markdown]
# # 3. Background and Motivation
#
# ### 3.1 Contextualização
#
# No panorama atual da era da informação, a produção de conteúdos digitais, particularmente notícias, ocorre a uma velocidade e volume sem precedentes. Para diversas áreas, tais como de profissionais de comunicação, investigadores ou empresas de análise de mercado, a capacidade de monitorizar múltiplas fontes de informação em tempo real é crucial. No entanto, a recolha manual e o armazenamento desestruturado destes dados tornam-se inviáveis quando escalamos para milhares de registos diários.
#
# ### 3.2 Motivação
#
# Este projeto surge da necessidade de automatizar o ciclo de vida dos dados: desde a sua aquisição (Web Scraping), passando pelo processamento e armazenamento robusto, até à recuperação eficiente.
#
# ### 3.3 Objetivo
#
# O objetivo principal é desenvolver um ecossistema integrado que recolha notícias de portais tecnológicos, armazená-las de forma indexada e forneça uma interface de consulta capaz de extrair insights relevantes sobre as tendências do setor.
#
# ### 3.4 Resultados Obtidos
# Através da nossa pipeline, conseguimos extrair, processar e indexar com sucesso centenas de artigos noticiosos no Redis. A infraestrutura demonstrou ser rápida na recuperação de informação através de queries em tempo real, validando o modelo de armazenamento chave-valor para este caso de uso.
#
# ### 3.5 Melhorias Futuras
# Para desenvolvimentos futuros, planeamos expandir as fontes de scraping para além dos portais tecnológicos e implementar um motor de busca mais avançado, permitindo pesquisas mais complexas e agregações analíticas nativas.
#
# ### 3.6 Dificuldades e resolução de problemas
#
# O processo de aquisição de dados (Web Scraping) foi desenhado e implementado de forma iterativa, dividindo-se em duas fases distintas para garantir a qualidade dos dados e o cumprimento dos requisitos:
#
# **1. Fase de Desenvolvimento e Validação (Execução Local):**
# Numa fase inicial, os scripts de extração em Python foram desenvolvidos e executados localmente. Esta abordagem manual permitiu-nos afinar os seletores, lidar com as variações na estrutura das páginas web (HTML) e garantir que a conversão para o formato JSON estava a ocorrer sem perda de informação. Durante este período, os dados foram sendo acumulados localmente.
#
# **2. Fase de Automatização (GitHub Actions):**
# Após a estabilização do código, procedemos à automatização do *pipeline*. Para cumprir o requisito de um *job scheduler*, implementámos um *workflow* nativo através do **GitHub Actions**. Esta transição final permitiu que a extração passasse a ocorrer de forma autónoma e programada, sem dependência das nossas máquinas físicas.

# %% [markdown]
# ## 4. Tecnologias utilizadas
#
# A tabela abaixo resume o stack tecnológico adotado para o desenvolvimento do projeto, garantindo a escalabilidade e a portabilidade do sistema.
#
# | Tecnologia | Função no Projeto | Justificação Técnica |
# | :--- | :--- | :--- |
# | **Python 3.12** | Linguagem Principal | Escolhida pela sua vasta biblioteca de suporte a Data Science, Web Scraping e integração com o Redis. |
# | **VS Code** | IDE | Utilizado para o desenvolvimento de scripts e gestão do Jupyter Notebook com integração de ambientes virtuais. |
# | **Docker** | Contentorização | Garante que o Redis corre num ambiente isolado e idêntico em qualquer máquina. |
# | **Redis** | Base de Dados NoSQL | Utilizado para o armazenamento ultrarrápido (formato Chave-Valor) e recuperação dos documentos JSON coletados. |

# %% [markdown]
# ## 5. Estrutura dos Dados (JSON)
#
# Durante a fase de extração (Web Scraping), cada notícia recolhida é limpa, processada e convertida num objeto JSON padronizado. Esta uniformização é crucial para garantir a integridade da base de dados e facilitar as *queries* no Redis.
#
# Abaixo está o dicionário de dados que compõe cada registo:
#
# * **`id_interno`**: Identificador único do registo no nosso ecossistema (por convenção, utilizamos o URL exato da publicação).
# * **`fonte`**: A plataforma, site ou jornal de origem da notícia.
# * **`titulo`**: O cabeçalho principal do artigo.
# * **`resumo`**: O *lead* ou descrição introdutória da notícia.
# * **`autor`**: A entidade ou jornalista que assina o artigo.
# * **`url`**: A hiperligação direta para a fonte original.
# * **`data_publicacao`**: A data e hora em que a notícia foi tornada pública no portal de origem.
# * **`data_extracao`**: O *timestamp* (formato ISO) gerado automaticamente no momento em que o nosso script recolheu a informação.
# * **`categoria`**: A secção temática sob a qual o portal classificou o artigo (ex: "Technology").
# * **`tags`**: Uma lista (*array*) de palavras-chave extraídas da publicação, essenciais para otimizar pesquisas e cruzamento de dados.
# * **`texto_completo`**: O corpo integral da notícia, purgado de formatações HTML desnecessárias e pronto a ser analisado.
#
# ### Exemplo:
#
# ```bash
# {
#     "id_interno": "https://pplware.sapo.pt/internet/analisa-pt-portugal-visto-atraves-dos-dados/",
#     "fonte": "Pplware",
#     "titulo": "analisa.pt: Portugal visto através dos dados",
#     "resumo": "O site analisa.pt surge como uma das ferramentas mais interessantes de escrutínio público em Portugal. Não é apenas um portal de dados.",
#     "autor": "Vítor M.",
#     "url": "https://pplware.sapo.pt/internet/analisa-pt-portugal-visto-atraves-dos-dados/",
#     "data_publicacao": "25 Abr 2026",
#     "data_extracao": "2026-04-25T13:38:41.008761",
#     "categoria": "Tecnologia",
#     "tags": [
#         "analisar",
#         "Portugal"
#     ],
#     "texto_completo": "25 Abr 2026·InternetComentar O siteanalisa.ptsurge como uma das ferramentas mais interessantes de escrutínio público em Portugal. Não é apenas um portal de dados..."
# }
# ```

# %% [markdown]
# ## Tarefa 1.1
#
# Para a recolha de dados, optámos por desenvolver scripts de Web Scraping em Python que extrairam notícias de três sites tecnológicos, Pplware, SAPO Tek e Exame Informática. Este serviço foi executado diariamente, durante vários dias consecutivos.
#
# Adicionalmente, implementámos o registo do processo através da biblioteca `logging` nativa do Python, guardando o histórico de sucessos e falhas da extração na pasta `logs/`. Os dados extraídos foram compilados e guardados na pasta `data/` em formato JSON.
#
# Todo o código-fonte, ficheiros de logs, JSONs e workflows podem ser consultados diretamente no nosso repositório:
#
# 🔗 **[Aceder ao Repositório GitHub do Projeto](https://github.com/BHenriques16/CDLE-Projeto1)**
#
# ### Guia de utilização do repositório
#
# ```bash
# git clone https://github.com/BHenriques16/CDLE-Projeto1
# cd CDLE-Projeto1
# ```
#
# - Para garantir que o codigo funciona, começe o contentor do Redis
#
# ```bash
# docker compose up -d
# ```
#
# - Configurar o ambiente virtual
# ```bash
# # Criar o ambiente virtual
# pyhton -m venv venv
#
# # Ativar o venv
# source venv/bin/activate    # se testar no Windows, utilize: venv\Scripts\activate
#
# # Instalar bibliotecas necessárias
# pip install -r requirements.txt
# ```
#
# - Execute o notebook
# ```bash
# jupyter notebook
# ```

# %% [markdown]
# ## Tarefa 1.2
#
# Carregamento do ficheiro JSON em memória e iteração pelos 5 primeiros registos

# %%
import json
import os

articles_path = 'data/articles.json'

# Load Json data in memory
if os.path.exists(articles_path):
    with open(articles_path, 'r', encoding='utf-8') as f:
        articles = json.load(f)

    print(f"File '{articles_path}' loaded successfully.")
    print(f"Total articles in memory: {len(articles)}")

    # Iterate through the first 5 articles and print their titles
    for i, article in enumerate(articles[:5]):
        print(f"Article {i + 1}:")

        # json.dumps() to print the article in a better format
        print(json.dumps(article, indent=4, ensure_ascii=False))

else:
    print(f"File '{articles_path}' not found. Please check the path and try again.")
# Out:
# File 'data/articles.json' loaded successfully.
# Total articles in memory: 544
# Article 1:
# {
#     "id_interno": "https://pplware.sapo.pt/internet/analisa-pt-portugal-visto-atraves-dos-dados/",
#     "fonte": "Pplware",
#     "titulo": "analisa.pt: Portugal visto através dos dados",
#     "resumo": "O site analisa.pt surge como uma das ferramentas mais interessantes de escrutínio público em Portugal. Não é apenas um portal de dados.",
#     "autor": "Vítor M.",
#     "url": "https://pplware.sapo.pt/internet/analisa-pt-portugal-visto-atraves-dos-dados/",
#     "data_publicacao": "25 Abr 2026",
#     "data_extracao": "2026-04-25T13:38:41.008761",
#     "categoria": "Tecnologia",
#     "tags": [
#         "analisar",
#         "Portugal"
#     ],
# ...

# %% [markdown]
# ## Tarefa 2.1
#
# Indexação dos artigos coletados no Redis
#
# ### Aviso de Infraestrutura (Docker)
# Antes de executar as células relativas à Tarefa 2, é necessário garantir que a base de dados Redis está a correr. Para levantar o ambiente idêntico ao desenvolvido pelo grupo, abra o terminal na raiz deste projeto e execute:
#
# `docker compose up -d`

# %%
import redis
import json

# Connect to Redis
r = redis.Redis(host='localhost', port=6379, decode_responses=True)

try:
    r.ping()
    print("Connected to Redis successfully.")
except redis.ConnectionError:
    print("Failed to connect to Redis. Please ensure Redis is running and try again.")

# Store articles in Redis
counter = 0

for article in articles:
    counter += 1
    # Create a unique key for each article
    key = f"article:{counter}"

    # Store the article as a JSON string in Redis
    r.set(key, json.dumps(article, ensure_ascii=False))

print(f"Stored {counter} articles in Redis.")
# Out:
# Connected to Redis successfully.
# Stored 544 articles in Redis.

# %% [markdown]
# ## Tarefa 2.2
#
# Recuperação de informação com recurso a queries

# %%
# Query 1: count the total number of articles stored in Redis
article_keys = r.keys('article:*')
print(f"Query 1: Total articles stored in Redis: {len(article_keys)}\n")

# Query 2: Retrieve a specific article by its key (e.g., article:3)
article_key = 'article:3'
article_data = r.get(article_key)

if article_data:
    article_retrieved = json.loads(article_data)
    print(f"Query 2: Article retrieved for key '{article_key}':")
    print(json.dumps(article_retrieved, indent=4, ensure_ascii=False))

# Query 3: Search for articles that contain a specific keyword in their title (e.g., "Tecnologia, Inteligencia Artificial")
keyword = "Inteligência Artificial"
matching_articles = []

for key in article_keys:
    doc  = json.loads(r.get(key))
    title = doc.get('titulo', '')

    # Check if the keyword is in lowercase
    if keyword.lower() in title.lower():
        matching_articles.append(doc)

print(f"Query 3: Articles containing the keyword '{keyword}' in their title:")
for i in matching_articles[:3]:  # Print the first 3 matching articles
    print(json.dumps(i, indent=4, ensure_ascii=False))
# Out:
# Query 1: Total articles stored in Redis: 544
#
# Query 2: Article retrieved for key 'article:3':
# {
#     "id_interno": "https://pplware.sapo.pt/motores/quase-80-considera-que-faz-sentido-termos-centrais-nucleares-em-portugal/",
#     "fonte": "Pplware",
#     "titulo": "Quase 80% considera que faz sentido termos centrais nucleares em Portugal",
#     "resumo": "Portugal não ficou alheio ao debate: chegou a hora de ponderar seriamente o nuclear? A maioria dos nossos leitores acredita que sim.",
#     "autor": "Ana Sofia Neto",
#     "url": "https://pplware.sapo.pt/motores/quase-80-considera-que-faz-sentido-termos-centrais-nucleares-em-portugal/",
#     "data_publicacao": "25 Abr 2026",
#     "data_extracao": "2026-04-25T13:38:44.897412",
#     "categoria": "Tecnologia",
#     "tags": [
#         "centrais nucleares",
#         "questão semanal"
#     ],
# ...
